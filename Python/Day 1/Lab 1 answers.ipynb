# %% [markdown]
# # ITI - Python - Lab 01

# %% [markdown]
# Q1:

# %%
x , y , z = True , "ITI" , 9

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'bool'>
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Q2:

# %%
a, b, c = input("Enter three values please: ").split()
# Out:
# Enter three values please: 10 20 30

# %% [markdown]
# print("1st value: ",a)
# print("1st value: ",b)
# print("1st value: ",c)

# %% [markdown]
# Q3

# %%
num = str(input("Enter a num: "))
print(len(num))
# Out:
# Enter a num: 99
# 2

# %% [markdown]
# Q4

# %%
num = int(input("Enter a number: "))
k = int(input("Enter K: "))

for i in range(k):
        num = num//10

print(num)
# Out:
# Enter a number: 1234
# Enter K: 2
# 12

# %% [markdown]
# Q5

# %%
nums = list(map(int, input("Enter Nums: ").split()))
print("Max", max(nums))
print("Min", min(nums))
# Out:
# Enter Nums: 10 20 30 40
# Max 40
# Min 10

# %% [markdown]
# Q6

# %%
x = int(input("Enter first num: "))
y = int(input("Enter first num: "))
print("minimum num is: ",min(x,y))
# Out:
# Enter first num: 50
# Enter first num: 70
# minimum num is:  50

# %% [markdown]
# Q7

# %%
salary = int(input("Enter Salary"))

if salary <1000:
    print("you r poor")
elif 1000 <= salary <20000:
    print("good salary")
else:
    print("you r rich")
# Out:
# Enter Salary10000
# good salary

# %% [markdown]
# Q8

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("you can drive")
else:
    print("you cant drive")
# Out:
# Enter your age: 20
# you can drive
